# %% [markdown]
# <a href="https://colab.research.google.com/github/varsha-varma-77/DSA/blob/main/Datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1: Install Jupyter
# Normally, we install Jupyter Notebook in a local environment using pip.

# %%
# !pip install jupyter

# %% [markdown]
# # Question 2: Load the Iris dataset using scikit-learn and convert it into a Pandas DataFrame

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %% [markdown]
# # Question 3: Display the first 5 rows of the dataset

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# # Question 4: Display the last 5 rows of the dataset

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %% [markdown]
# # Question 5: Display the first 20 rows of the dataset

# %%
df.head(20)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# # Question 6: Display the last 20 rows of the dataset

# %%
df.tail(20)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# ...

# %% [markdown]
# # Question 7: Find the number of rows and columns in the dataset

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Question 8: Print the column names of the dataset

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %% [markdown]
# # Question 9: Check the data type of each column

# %%
df.dtypes
# Out:
# sepal length (cm)     float64
# sepal width (cm)      float64
# petal length (cm)     float64
# petal width (cm)      float64
# species              category
# dtype: object

# %% [markdown]
# # Question 10: Display a summary of the dataset using info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %% [markdown]
# # Question 11: Generate statistical summary of the dataset using describe()

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# # Question 12: Find the mean, median, and standard deviation of sepal_length

# %%
df['sepal length (cm)'].mean(), df['sepal length (cm)'].median(), df['sepal length (cm)'].std()
# Out:
# (np.float64(5.843333333333334), 5.8, 0.8280661279778629)

# %% [markdown]
# # Question 13: Find the minimum and maximum values of petal_width

# %%
df['petal width (cm)'].min(), df['petal width (cm)'].max()
# Out:
# (0.1, 2.5)

# %% [markdown]
# # Question 14: Check whether the dataset contains missing values

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %% [markdown]
# # Question 15: Count the number of samples for each species

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Question 16: Select the first 10 rows using iloc

# %%
df.iloc[:10]
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
# 6  setosa
# 7  setosa
# 8  setosa
# 9  setosa

# %% [markdown]
# # Question 17: Select only the columns sepal_length and sepal_width

# %%
df[['sepal length (cm)', 'sepal width (cm)']]
# Out:
#      sepal length (cm)  sepal width (cm)
# 0                  5.1               3.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# 4                  5.0               3.6
# ..                 ...               ...
# 145                6.7               3.0
# 146                6.3               2.5
# 147                6.5               3.0
# 148                6.2               3.4
# 149                5.9               3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# # Question 18: Select rows where sepal_length is greater than 6.0

# %%
df[df['sepal length (cm)'] > 6.0]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 54                 6.5               2.8                4.6               1.5
# 56                 6.3               3.3                4.7               1.6
# ..                 ...               ...                ...               ...
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
#
#         species
# ...

# %% [markdown]
# # Question 19: Select all samples that belong to the species Iris-virginica

# %%
df[df['species'] == 'virginica']
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %% [markdown]
# # Question 20: Using loc, extract rows 20 to 30 and columns petal_length and petal_width

# %%
df.loc[20:30, ['petal length (cm)', 'petal width (cm)']]
# Out:
#     petal length (cm)  petal width (cm)
# 20                1.7               0.2
# 21                1.5               0.4
# 22                1.0               0.2
# 23                1.7               0.5
# 24                1.9               0.2
# 25                1.6               0.2
# 26                1.6               0.4
# 27                1.5               0.2
# 28                1.4               0.2
# 29                1.6               0.2
# 30                1.6               0.2

# %% [markdown]
# # Question 21: Filter rows where petal_length is greater than 5.0

# %%
df[df['petal length (cm)'] > 5.0]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 83                 6.0               2.7                5.1               1.6
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %% [markdown]
# # Question 22: Filter rows where sepal_width is less than 3.0

# %%
df[df['sepal width (cm)'] < 3.0]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# 55                 5.7               2.8                4.5               1.3
# 57                 4.9               2.4                3.3               1.0
# 58                 6.6               2.9                4.6               1.3
# 59                 5.2               2.7                3.9               1.4
# 60                 5.0               2.0                3.5               1.0
# 62                 6.0               2.2                4.0               1.0
# 63                 6.1               2.9                4.7               1.4
# ...

# %% [markdown]
# # Question 23: Apply multiple conditions: sepal_length > 6.0 AND petal_width > 2.0

# %%
df[(df['sepal length (cm)'] > 6.0) & (df['petal width (cm)'] > 2.0)]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 102                7.1               3.0                5.9               2.1
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 109                7.2               3.6                6.1               2.5
# 112                6.8               3.0                5.5               2.1
# 115                6.4               3.2                5.3               2.3
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 120                6.9               3.2                5.7               2.3
# 124                6.7               3.3                5.7               2.1
# ...

# %% [markdown]
# # Question 24: Count how many samples satisfy the above condition

# %%
df[(df['sepal length (cm)'] > 6.0) & (df['petal width (cm)'] > 2.0)].shape[0]
# Out:
# 22

# %% [markdown]
# # Question 25: Sort the dataset by sepal_length in ascending order

# %%
df.sort_values('sepal length (cm)')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 13                 4.3               3.0                1.1               0.1
# 8                  4.4               2.9                1.4               0.2
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
#        species
# 13      setosa
# ...

# %% [markdown]
# # Question 26: Sort the dataset by petal_width in descending order

# %%
df.sort_values('petal width (cm)', ascending=False)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 144                6.7               3.3                5.7               2.5
# 109                7.2               3.6                6.1               2.5
# 100                6.3               3.3                6.0               2.5
# 114                5.8               2.8                5.1               2.4
# 136                6.3               3.4                5.6               2.4
# ..                 ...               ...                ...               ...
# 13                 4.3               3.0                1.1               0.1
# 12                 4.8               3.0                1.4               0.1
# 9                  4.9               3.1                1.5               0.1
# 37                 4.9               3.6                1.4               0.1
# 32                 5.2               4.1                1.5               0.1
#
#        species
# 144  virginica
# ...

# %% [markdown]
# # Question 27: Display the top 5 rows after sorting by petal_length

# %%
df.sort_values('petal length (cm)', ascending=False).head(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 122                7.7               2.8                6.7               2.0
# 105                7.6               3.0                6.6               2.1
# 131                7.9               3.8                6.4               2.0
#
#        species
# 118  virginica
# 117  virginica
# 122  virginica
# 105  virginica
# 131  virginica

# %% [markdown]
# # Question 28: Group the dataset by species

# %%
grouped = df.groupby('species')
# Out:
# /tmp/ipython-input-3754222865.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby('species')

# %% [markdown]
# # Question 29: Compute the mean of all numerical features for each species

# %%
grouped.mean()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %% [markdown]
# # Question 30: Compute the maximum petal length for each species

# %%
grouped['petal length (cm)'].max()
# Out:
# species
# setosa        1.9
# versicolor    5.1
# virginica     6.9
# Name: petal length (cm), dtype: float64

# %% [markdown]
# # Question 31: Find which species has the largest average sepal length

# %%
grouped['sepal length (cm)'].mean().idxmax()
# Out:
# 'virginica'

# %% [markdown]
# # Question 32: Create a new column sepal_area = sepal_length × sepal_width

# %%
df['sepal_area'] = df['sepal length (cm)'] * df['sepal width (cm)']

# %% [markdown]
# # Question 33: Use apply() to convert all column names to uppercase

# %%
df.columns = df.columns.to_series().apply(lambda x: x.upper())

# %% [markdown]
# # Question 34: Use applymap() to calculate the length of each numeric value (after converting to string)

# %%
df.applymap(lambda x: len(str(x)) if isinstance(x, (int, float)) else len(str(x)))
# Out:
# /tmp/ipython-input-1679264738.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: len(str(x)) if isinstance(x, (int, float)) else len(str(x)))
#      SEPAL LENGTH (CM)  SEPAL WIDTH (CM)  PETAL LENGTH (CM)  PETAL WIDTH (CM)  \
# 0                    3                 3                  3                 3
# 1                    3                 3                  3                 3
# 2                    3                 3                  3                 3
# 3                    3                 3                  3                 3
# 4                    3                 3                  3                 3
# ..                 ...               ...                ...               ...
# 145                  3                 3                  3                 3
# 146                  3                 3                  3                 3
# ...

# %% [markdown]
# # Question 35: Round all numerical values to 2 decimal places

# %%
df.round(2)
# Out:
#      SEPAL LENGTH (CM)  SEPAL WIDTH (CM)  PETAL LENGTH (CM)  PETAL WIDTH (CM)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        SPECIES  SEPAL_AREA
# ...

# %% [markdown]
# # Question 36: Rename column sepal_length to SL

# %%
df.rename(columns={'SEPAL LENGTH (CM)': 'SL'}, inplace=True)

# %% [markdown]
# # Question 37: Drop the column sepal_area

# %%
df.drop(columns=['SEPAL_AREA'], inplace=True)

# %% [markdown]
# # Question 38: Make a copy of the dataset

# %%
df_copy = df.copy()

# %% [markdown]
# # Question 39: Reset the index of the DataFrame

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Question 40: Check for duplicate rows in the dataset

# %%
df.duplicated().sum()
# Out:
# np.int64(1)
